# %%
import json
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from mplsoccer import Pitch, VerticalPitch

# %% [markdown]
# # Exploratory Data Analysis

# %%
### Wyscout Data legacy version tagnames mapping########
tags2name = pd.read_csv("/home/shivargha/football_analytics/data/wyscout_data/tags2name.csv",sep=";")
tags_dict = tags2name.set_index("Tag").to_dict()["Description"]
tags_dict
# Out:
# {101: 'Goal',
#  102: 'Own goal',
#  301: 'Assist',
#  302: 'Key pass',
#  1901: 'Counter attack',
#  401: 'Left foot',
#  402: 'Right foot',
#  403: 'Head/body',
#  1101: 'Direct',
#  1102: 'Indirect',
#  2001: 'Dangerous ball lost',
#  2101: 'Blocked',
#  801: 'High',
#  802: 'Low',
#  1401: 'Interception',
#  1501: 'Clearance',
#  201: 'Opportunity',
#  1301: 'Feint',
#  1302: 'Missed ball',
#  501: 'Free space right',
#  502: 'Free space left',
#  503: 'Take on left',
#  504: 'Take on right',
#  1601: 'Sliding tackle',
#  601: 'Anticipated',
#  602: 'Anticipation',
#  1701: 'Red card',
#  1702: 'Yellow card',
#  1703: 'Second yellow card',
#  1201: 'Position: Goal low center',
#  1202: 'Position: Goal low right',
#  1203: 'Position: Goal center',
#  1204: 'Position: Goal center left',
#  1205: 'Position: Goal low left',
#  1206: 'Position: Goal center right',
#  1207: 'Position: Goal high center',
#  1208: 'Position: Goal high left',
#  1209: 'Position: Goal high right',
# ...

# %%
#### Create a Pitch Map for wyscout data ####
pitch1 = Pitch(pitch_type='wyscout',  # example plotting a tracab pitch
              pitch_length=100, pitch_width=100,
              axis=True, label=True) 
pitch2 = Pitch(pitch_type='wyscout',  # example plotting a tracab pitch
              pitch_length=100, pitch_width=100,
              axis=True, label=True) 
fig1, ax1 = pitch1.draw()
fig2, ax2 = pitch2.draw()

# %%
body_part_dict = { 401: 'Left foot',402: 'Right foot',403: 'Head/body',}

# %%
#### Plotting all the unblocked shots ####

data_folder = "/home/shivargha/football_analytics/data/wyscout_data/events/"


for file in os.listdir(data_folder):
    #### open the data #####
    with open(data_folder+file) as f:
        data = json.load(f)
    
    for index,row in enumerate(data):
        if row["eventName"] == "Shot":
            tags = [tags_dict[i["id"]] for i in row["tags"]]
            #print(tags)
            if "Goal" in tags:
                #print("Yes")
                start_x,start_y = data[index]["positions"][0]["x"],data[index]["positions"][0]["y"]
                shotCircle=plt.Circle((start_x,start_y),1,color="red")
                ax1.add_patch(shotCircle)
            else:
                if "Blocked" in tags:
                    pass
                else:
                    start_x,start_y = data[index]["positions"][0]["x"],data[index]["positions"][0]["y"]
                    shotCircle=plt.Circle((start_x,start_y),1,color="blue")
                    ax2.add_patch(shotCircle)

# %%
fig1

# %%
fig2

# %% [raw]
# #### features to be used ###
# 1. Shot Locations
# 2. Shot Distance from Goal
# 3. Shot Angle
# 4. Body Part Used
# 5. Match Half
# 6. Skilled Foot - Y or N
#
#
# target-variable : Shot_Result (Goal or No Goal)

# %%
###player details db###
with open("/home/shivargha/football_analytics/data/wyscout_data/players.json") as f:
    players_db = json.load(f)

# %%
data_folder = "/home/shivargha/football_analytics/data/wyscout_data/events/"

def create_shot_dataset():
    
    
    df_list = []
    
    for file in os.listdir(data_folder):
        #### open the data #####
        with open(data_folder+file) as f:
            data = json.load(f)
    
        for index,row in enumerate(data):
            if row["eventName"] == "Shot":
                tags = [tags_dict[i["id"]] for i in row["tags"]]
                if "Blocked" in tags:
                    pass
                else:

                    if "Goal" in tags:
                        target_value = 1
                    else:
                        target_value = 0

                    wysc_x,wysc_y = data[index]["positions"][0]["x"],data[index]["positions"][0]["y"]
                    #now we are interested in distance from the goal as well as the angle formed with the goal
                    #Wyscouts pitch has its origin at the top left of the pitch and is 100m x 100m
                    #therefore x and y represent percentage of nearness to top left corner 
                    #most pitches are 105 meters by 68 so we will go with that
                    X_loc,Y_loc  = (100 - wysc_x)*1.05,(wysc_y)*0.68 


                    ###Calculate Goal Distance###
                    centre_dis = abs(Y_loc-50)*0.68
                    distance_from_goal = np.sqrt(X_loc**2 + centre_dis**2)


                    #####Calculate the Angle####
                    #we are interested in the angle made between the width of the goal and the
                    #straight line distance to the shot location. A goal is 7.32 meters wide
                    shot_angle = np.where(np.arctan(7.32 * X_loc / (X_loc**2 + centre_dis**2 - (7.32/2)**2)) > 0, \
                                          np.arctan(7.32 * X_loc/(X_loc**2 + centre_dis**2 - (7.32/2)**2)), \
                                          np.arctan(7.32 * X_loc/(X_loc**2 + centre_dis**2 - (7.32/2)**2)) + np.pi)

                    body_part_tags = [401,402,403]
                    body_part = [tags_dict[i["id"]] for i in row["tags"] if i["id"] in body_part_tags][0]
                   
                    match_half = row["matchPeriod"]
                    player_id = row["playerId"]
                    ###get preferred foot of the player taking the shoot##
                    for player in players_db:
                        if player["wyId"] == player_id:
                            pref_foot = player["foot"]

                    if pref_foot in body_part.lower():
                        skilled_foot = "Yes"
                    else:
                        skilled_foot = "No"

                    df_list.append([X_loc,Y_loc,distance_from_goal,shot_angle,body_part,\
                                    skilled_foot,match_half,target_value])
                    
    df = pd.DataFrame(df_list, columns=['X_loc','Y_loc','Distance','Angle','Body Part',\
                                       'Skilled_Foot','Match_Half','Target_Value'])
                    
    return df
df = create_shot_dataset()

# %%
df.head()
# Out:
#    X_loc  Y_loc   Distance                Angle   Body Part Skilled_Foot  \
# 0  12.60  27.88  19.621665  0.24327716981138675  Right foot          Yes
# 1  15.75  35.36  18.632458    0.332583910327655   Left foot          Yes
# 2   4.20  35.36  10.804907   0.2891372308558594   Head/body           No
# 3  19.95  22.44  27.371885  0.19591732474111048   Left foot           No
# 4  26.25  20.40  33.078677  0.17594607764306963  Right foot          Yes
#
#   Match_Half  Target_Value
# 0         1H             1
# 1         1H             0
# 2         1H             1
# 3         1H             0
# 4         1H             0
